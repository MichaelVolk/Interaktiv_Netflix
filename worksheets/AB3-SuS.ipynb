# %%
# Hier nichts ändern!
import sys
sys.path.append("../code")
from setup_AB3 import *

# %% [markdown]
# <img src = "../figs/cammp.png" style="height:5em; width:auto" align="right">
#
#
# # Netflix | Arbeitsblatt 3: Berechnung einer Zerlegung in U und M <i class="fa fa-area-chart" style="font-size:26px"></i>
#
# Der Netflixdatensatz beinhaltet nur die Rating-Tabelle $R$. Wie können wir  die User-Tabelle $U$ und die Movie-Tabelle $M$ ausgehend von $R$ berechnen?  Bevor wir uns mit dieser Frage beschäftigen, treffen wir zwei Annahmen:

# %% [markdown]
# <div id="information" class="alert alert-success">
#     <h2><i class="fas fa-info" style="font-size:36px"></i> &nbsp;  Annahme</h2>
#     <ol>
#         <li>Die Einträge  in $U$ und $M$ dürfen ab jetzt <strong>beliebige Zahlenwerte</strong> annehmen.  Die Einträge sind dann zwar nicht mehr so schön interpretierbar, dafür können wir die Rating-Tabelle womöglich leichter in $U$ und $M$ zerlegen.</li>
#         <li>Wir berücksichtigen weiterhin nur zwei Eigenschaften: <strong>Eigenschaft 1 (E1)</strong> und <strong>Eigenschaft 2 (E2)</strong>. Wir legen  nicht  fest, welche Eigenschaften wir genau betrachten. Neben dem Genre könnten durchaus auch andere Eigenschaften relevant sein. Zum Beispiel eine besonders berühmte Schauspielerin.</li>
#     </ol>
# </div>

# %% [markdown]
# ## 1) Zerlegung per Hand berechnen
#
# Wir suchen für die Rating-Matrix $R1$
# <div style="text-align:center">
# <img src="../figs/AB2_A1_a.png" width="220", class="center">
# </div>
#
# eine Zerlegung in eine User-Matrix $U1$ und eine Movie-Matrix $M1$
# <div style="text-align:center">
# <img src="../figs/AB3_A1_a_UM.png" width="450", class="center">
# </div>

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#     <h3><i class="fa fa-laptop" style="font-size:30px"></i> <br><br>a) Werte von U1 und M1</h3>
#     Bestimme Werte für die Einträge von <strong>U1</strong> und  <strong>M1</strong>, sodass deine Formeln von Aufgabenblatt 2 für alle Bewertungen in <strong>R1</strong> erfüllt sind. Gib die gefundenen Werte im Code für die <strong>None</strong> ein und führe den Code aus. Vergleiche deine User-Matrix und deine Movie-Matrix mit denen deines Gruppenmitglieds. Findest du noch eine zweite passende Zerlegung?
#     <hr>  <!-- Horizontale Linie -->
#     <i class="fas fa-wrench" style="font-size: 20px"></i> &nbsp;  <strong>Hinweise:</strong>
#     Dezimalzahlen werden mit einem Punkt eingegeben. Zum Beispiel: <strong>1.5</strong>.
#     <hr>  <!-- Horizontale Linie -->
#     <a href="../help/help3_1.ipynb"><i class="fas fa-life-ring" style="font-size:20px"></i> &nbsp;Tipp</a> <span style="margin-right: 20px;"></span>   <!-- Link zum Tipp anpassen oder Zeile löschen-->
# </div>

# %%
R1 = np.array([[5, 3], 
             [3, 1]])

# Zerlegung 1
U1 =  np.array([[None, None],
                [None, None]])

M1 =  np.array([[None, None],
                [None, None]])

# Berechnung der Vorhersage-Matrix
checkDecomposition(U1, M1)
# Out:
# <div class="alert alert-danger"> <i class="fas fa-times"></i> Ersetzen alle None</p></div>

# %% [markdown]
# ## Zwischenfazit
# Bei   kleinen Rating-Matrizen ist es möglich *per Hand* eine Zerlegung in $U$ und $M$ zu finden. Bei   großen Rating-Matrizen wird das schwierig... und die Matrix ist beim Netflixdatensatz mit 480189 Zeilen (= <i class="fa fa-user" style="font-size:20px"></i> ) und 17770 Spalten (=  <i class="fa fa-film" style="font-size:20px"></i> ) *ziiiiemlich* groß. Wir werden die Suche nach einer passenden Zerlegung dem Computer überlassen und dazu auf dem nächsten Arbeitsblatt ein schrittweises Verfahren entwickeln.
#
# Vorab benötigen wir noch ein Fehlermaß, mit dem wir (und der Computer) bewerten können, ob **eine gefundene Zerlegung schon ausreichend gut** ist. Wir definieren dazu in dieser Aufgabe ein Fehlermaß, mit dem wir folgende Fragen beanworten können: *Wann ist eine Zerlegung gut? Wann ist eine Zerlegung besser als eine andere?*
# ___

# %% [markdown]
# ## 2) Bewertung einer gefundenen Zerlegung
#
# Wir betrachten die folgende Rating-Matrix
#
#
# <div style="text-align:center">
# <img src="../figs/AB2_A2_a.png" width="300", class="center">
# </div>
#
# Gegeben sind außerdem drei Zerlegungen, die die Ratings in $R$ alle drei nicht exakt widerspiegeln.
#
# **Zerlegung 1:**
#
# $U4 = \begin{pmatrix}
#   1 & 0.5    \\
#   0.5 & 1.5   \end{pmatrix} \;\; \text{und} \;\;
#  M4 = \begin{pmatrix}
#   2 & 1 & 0 & 2  \\
#   0 & 1 & 2 & 1 \end{pmatrix} $
#
#
# **Zerlegung 2:**
#
# $U5 = \begin{pmatrix}
#   2 & 0   \\
#   1 & 1.5  \end{pmatrix} \;\; \text{und} \;\;
#  M5 = \begin{pmatrix}
#  1.5 & 1 & 1 & 2 \\
#   0 & 2 & 1 & 2\end{pmatrix} $
#
#
# **Zerlegung 3:**
#
# $U6 = \begin{pmatrix}
#   1.8 & 0   \\
#   1 & 1.5  \end{pmatrix} \;\; \text{und} \;\;
#  M6 = \begin{pmatrix}
#  1.5 & 1 & 1 & 1.8 \\
#   0 & 2 & 1.2 & 2\end{pmatrix} $

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#     <h3><i class="fa fa-laptop" style="font-size:30px"></i> <br><br>a) Vergleich verschiedener Vorhersage-Matrizen  </h3>
#    Führe die drei folgenden Codefelder aus. Für alle drei Zerlegungen wird das Produkt aus der User- und der Movie-Matrix berechnet. Das Ergebnis ist eine Matrix, die alle Vorhersagen der Bewertungen (engl. predictions) enthält. Wir nennen diese Matrix deswegen auch <strong>Vorhersage-Matrix $P$</strong>. Zum leichteren Vergleich wird jedes Mal auch die Rating-Matrix $R$ erneut angezeigt.
# </div>

# %%
# Zerlegung 1
U4 = np.array([[1, 0.5], 
              [0.5, 1.5]])

M4 = np.array([[2, 1, 0, 2], 
                [0, 1, 2, 1]])

# Berechnung der Vorhersage-Matrix
P4 = calc_pred(U4, M4)

# %%
# Zerlegung 2
U5 = np.array([[2, 0], 
              [1, 1.5]])

M5 = np.array([[1.5, 1, 1, 2], 
                [0, 2, 1, 2]])

# Berechnung der Vorhersage-Matrix
P4 = calc_pred(U5, M5)

# %%
# Zerlegung 3
U6 = np.array([[1.8, 0], 
              [1, 1.5]])

M6 = np.array([[1.5, 1, 1, 1.8], 
                [0, 2, 1.2, 2]])

# Berechnung der Vorhersage-Matrix
P4 = calc_pred(U6, M6)

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#     <h3><i class="fa fa-pencil-square-o" style="font-size:30px"></i> <br><br>b) Fehler berechnen</h3>
#    Diskutiere mit deinem Gruppenmitglied, wie  <strong>die Abweichung bzw. der Fehler</strong> zwischen der jeweiligen Vorhersage-Matrix und der tatsächlichen Rating-Matrix $R$ berechnet werden kann. Berechne dann für jede der drei Zerlegungen den Fehler. Die Berechnung kannst du entweder mit Stift und Papier oder in der nächsten Codezelle durchführen, die funktioniert wie ein Taschenrechner.
#     <hr>  <!-- Horizontale Linie -->
#     <a href="../help/help4_1.ipynb"><i class="fas fa-life-ring" style="font-size:20px"></i> &nbsp;Tipp</a> <span style="margin-right: 20px;"></span>   <!-- Link zum Tipp anpassen oder Zeile löschen-->
# </div>

# %%
# Hier ist Platz für deine Berechnungen:

# %%
promt_3_2_b()
# Out:
# ...
# Output()

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#     <h3><i class="fa fa-laptop" style="font-size:30px"></i> <br><br>c) Allgemeine Formel für den Fehler</h3>
#     Damit wir den Fehler für eine beliebige Rating-Matrix und eine gefundene Zerlegung in <strong>U</strong> und <strong>M</strong> berechnen können, stellen wir in dieser Teilaufgabe eine allgemeine Formel für den Fehler auf.
#     <hr>
#     Stelle eine Formel auf, mit der der Fehler zwischen der folgenden <strong>Rating-Matrix R</strong> und der <strong>Vorhersage-Matrix P</strong>
#     <div style="text-align:left">
#         <img src="../figs/AB3_A2_b_RP.png" width="380", class="center">
#     </div>
#     berechnet werden kann. In deiner Formel kannst du alle Variablen verwenden, die in der Rating-Matrix $R$ (<strong>r11</strong>, <strong>r12</strong>,...) und der Vorhersage-Matrix $P$ (<strong>p11</strong>, <strong>p12</strong>,...) vorkommen. Ersetze das <strong>None</strong> durch deine Formel und führe den Code aus.
#     <hr>  <!-- Horizontale Linie -->
#     <i class="fas fa-wrench" style="font-size: 20px"></i> &nbsp;  <strong>Hinweise:</strong>
#     <ul>
#         <li>Addieren und subtrahieren:  <strong>2 + 3</strong> oder <strong>2 - 4</strong></li>
#         <li>Multiplizieren und dividieren: <strong>2 * 6</strong> oder <strong>6 / 3</strong></li>
#         <li>Quadrieren: <strong>4**2</strong></li>
#         <li>Den Betrag einer Zahl berechnen: <strong>abs(-4)</strong></li>
#     </ul>
#     <hr>  <!-- Horizontale Linie -->
#     <a href="../help/help4_1_A.ipynb"><i class="fas fa-life-ring" style="font-size:20px"></i> &nbsp;Tipp</a> <span style="margin-right: 20px;"></span>   <!-- Link zum Tipp anpassen oder Zeile löschen-->
# </div>

# %%
# Formel für den Fehler
def error_P(r11,r12,r21,r22,p11,p12,p21,p22): 
     return None # Gib hier deine Formel ein. 

# Hier nichts ändern!
checkError_P(error_P,R_24,U4,M4,U5,M5,U6,M6)

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#     <h3> <i class="fa fa-laptop" style="font-size:36px"></i> <br><br>d) Weitere Verallgemeinerung</h3>
#     Wir definieren die Formel für den Fehler in Abhängigkeit der Einträge von $U$ und $M$. Denn dies sind gerade die Einträge, die wir (bzw. der PC mithilfe eines Optimierungsverfahrens) so wählen wollen, dass der Fehler zwischen Rating-Matrix und Vorhersage-Matrix minimal wird.
#     <hr>
#     Stelle eine Formel auf mit der der Fehler zwischen der folgenden <strong>Rating-Matrix R</strong> und der <strong>Vorhersage-Matrix P</strong>
#     <div style="text-align:left">
# <img src="../figs/AB3_A2_b_R.png" width="180", class="center"> <img src="../figs/AB3_A2_b_P.png" width="430", class="center">
# </div>
#     berechnet werden kann. Ersetze das <strong>None</strong> durch eine Formel für den Fehler, die nur noch von den Einträgen von $R$ (<strong>r11</strong>, <strong>r12</strong>,...), von $U$ (<strong>u11</strong>, <strong>u12</strong>,...) und von $M$ (<strong>m11</strong>, <strong>m12</strong>,...) abhängt.  Führe den Code aus.
#     <hr>  <!-- Horizontale Linie -->
#     <a href="../help/help4_1_B.ipynb"><i class="fas fa-life-ring" style="font-size:20px"></i> &nbsp;Tipp</a> <span style="margin-right: 20px;"></span>   <!-- Link zum Tipp anpassen oder Zeile löschen-->
# </div>

# %%
# Formel für den Fehler
def error(r11,r12,r21,r22,u11,u12,u21,u22,m11,m12,m21,m22): 
     return None # Gib hier deine Formel ein. 

# Hier nichts ändern!
checkError(error,R_24,U4,M4,U5,M5,U6,M6);

# %% [markdown]
# <div id="information" class="alert alert-success">
#     <h2><i class="fas fa-info" style="font-size:36px"></i> &nbsp;  Fehlende Bewertungen</h2>
#     Tatsächlich sind in der Rating-Matrix nicht alle Einträge bekannt. Bei der Berechnung des Fehlers sollen fehlende Einträge  nicht berücksichtigt werden. Dazu wurde deine Formel für den Fehler um einen Programmierbefehl von Python ergänzt. Dieser fängt  alle Terme ab, bei denen die Bewertung nicht bekannt ist.
# </div>

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#     <h3><i class="fa fa-pencil-square-o" style="font-size:30px"></i> <br><br>e) Vergleichbarkeit des Fehlers</h3>
#     Angenommen wir haben je eine Vorhersage-Matrix
#     <ul>
#         <li>für eine Rating-Matrix mit <strong>1000 Usern und 1500 Filmen</strong> und</li>
#         <li>für eine andere Rating-Matrix mit <strong>10 Usern und 15 Filmen</strong>.</li>
#     </ul>
#     berechnet. Kann das Fehlermaß aus <strong>Aufgabe b</strong> verwendet werden, um vergleichen zu können, welche Vorhersage-Matrix (und damit auch welche Zerlegung) besser ist? Begründe deine Antwort.
# </div>

# %%
promt_3_2_d()
# Out:
# ...
# Output()

# %% [markdown]
# # Diskussion im Plenum <img src="../figs/discussion.png" width="50"/>
# **Wir werden eure bisherigen Ergebnisse gemeinsam diskutieren!**
#
#
# ### [Aktuell nicht verfügbar!] Zusatzaufgabe zur Matrix-Schreibweise
#  Mit verschiedenen Rechenregeln für Matrizen kann man die Formel für den Fehler enorm abkürzen. Diejenigen, die bereits mit Matrizen gearbeitet haben, können den Fehler in Matrizen-Schreibweise in dieser  [Zusatzaufgabe](./Zusatzmaterial/Zusatz_Error_Matrix_Schreibweise-SuS.ipynb) herleiten.
#
#
# ____
# **Frage deine Betreuer/innen, mit welchem der folgenden beiden Arbeitsblätter du weiterarbeiten sollst.**
# 1. Die Anwendung und Untersuchung eines Optimierungsverfahrens  auf  [Arbeitsblatt 4 - Kurzversion](./AB4_A-SuS.ipynb) oder
# 2. [Aktuelle nicht verfügbar!] Die eigenständige Entwicklung eines Optimierungsverfahrens auf [Arbeitsblatt 4 - Langversion](./AB4-SuS.ipynb)
#
#
#   ___
# <a rel=“license” href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons Lizenzvertrag" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a> Dieses Werk ist lizenziert unter einer <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Namensnennung - Weitergabe unter gleichen Bedingungen 4.0 International Lizenz</a>
#
# Autorin: Sarah Schönbrodt
