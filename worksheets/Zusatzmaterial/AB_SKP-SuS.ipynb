# %%
# Hier nichts ändern!
import sys
sys.path.append("../../code")
from setup_SKP import *

# %% [markdown]
# # Zusatzaufgabe | Große oder kleine Ratings!?
#
# Wir betrachten die folgende Rating-Matrix $R$ und eine Zerlegung in  User-Matrix $U$ und  Movie-Matrix $M$:
#
# <div style="text-align:left">
# <img src="../../figs/SKP.png" width="500", class="center">
# </div>
#
#
# Die Zeilen der User-Matrix und die Spalten der Movie-Matrix können wir auch als Vektoren betrachten:
#
# <div style="text-align:left">
# <img src="../../figs/SKP_Vecs.png" width="500", class="center">
# </div>

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:36px"></i>&nbsp; <br><br> a) Geometrische Interpretation</h3>
#     Führe den folgenden Code aus. Die Zeilenvektoren der User-Matrix und die Spaltenvektoren der Movie-Matrix werden in ein Koordinatensystem eingezeichnet.
# </div>

# %%
# Hier nichts ändern!
plotUserMovieVectors()

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-pencil-square-o" style="font-size:36px"></i>&nbsp; <br><br> b) Mathematisches Grundkonzept</h3>
#     Hinter der Berechnung eines Ratings aus eine Zeilevektor der User-Matrix und einem Spaltenvektor der Movie-Matrix verbirgt sich das Skalarprodukt.
#     Begründe, inwieweit sich im zweidimensionalen Fall geometrisch begründen lässt, wann das Ergebnis ein größeres bzw. kleineres Rating liefert.  Nutze dazu die geometrische Darstellung und die Definition des Skalarprodukt. Bei Bedarf kannst du im Internet nach der Definition suchen.
#     <hr>
#     <a href="../../help/help_SKP.ipynb"><i class="fas fa-life-ring" style="font-size:20px"></i> &nbsp;Definition des Skalarprodukts</a> <span style="margin-right: 20px;"></span>   <!-- Link zum Tipp anpassen oder Zeile löschen-->
# </div>

# %%
promt_SKP_b()

# %% [markdown]
# ____
# **Zusatzinfo:**
# Diese Interpretation lässt sich genauso auch auf Vektoren mit mehr Einträgen übertragen. Beispielsweise, wenn man nicht nur die 2 Eigenschaften (Action & Comedy), sondern noch weitere Eigenschaften berücksichtigen würde.
#
# ____
# <a rel=“license” href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons Lizenzvertrag" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /> Dieses Werk ist lizenziert unter einer <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Namensnennung - Weitergabe unter gleichen Bedingungen 4.0 International Lizenz</a>
# Autorin: Sarah Schönbrodt

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-laptop" style="font-size:36px"></i>&nbsp; <br><br> a) Geometrische Interpretation</h3>
#     Führe den folgenden Code aus. Die Zeilenvektoren der User-Matrix und die Spaltenvektoren der Movie-Matrix werden in ein Koordinatensystem eingezeichnet.
# </div>

# %%
# Hier nichts ändern!
plotUserMovieVectors()

# %% [markdown]
# <div id="exercise" class="alert alert-info">
#   <h3><i class="fa fa-pencil-square-o" style="font-size:36px"></i>&nbsp; <br><br> b) Mathematisches Grundkonzept</h3>
#     Hinter der Berechnung eines Ratings aus eine Zeilevektor der User-Matrix und einem Spaltenvektor der Movie-Matrix verbrgt sich das Skalarprodukt.
#     Begründe, inwieweit sich im zweidimensionalen Fall geometrisch begründen lässt, wann das Ergebnis ein größeres bzw. kleineres Rating liefert.  Nutze dazu die geometrische Darstellung und die Definition des Skalarprodukt. Bei Bedarf kannst du im Internet nach der Definition suchen.
#     <hr>
#     <a href="../../help/help_SKP.ipynb"><i class="fas fa-life-ring" style="font-size:20px"></i> &nbsp;Definition des Skalarprodukts</a> <span style="margin-right: 20px;"></span>   <!-- Link zum Tipp anpassen oder Zeile löschen-->
# </div>

# %%
promt_SKP_b()

# %% [markdown]
# ____
# **Zusatzinfo:**
# Diese Interpretation lässt sich genauso auch auf Vektoren mit mehr Einträgen übertragen. Beispielsweise, wenn man nicht nur die 2 Eigenschaften (Action & Comedy), sondern noch weitere Eigenschaften berücksichtigen würde.
#
# ____
# <a rel=“license” href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="Creative Commons Lizenzvertrag" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br /> Dieses Werk ist lizenziert unter einer <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Creative Commons Namensnennung - Weitergabe unter gleichen Bedingungen 4.0 International Lizenz</a>
# Autorin: Sarah Schönbrodt
