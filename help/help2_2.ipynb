# %% [markdown]
# # Tipp 2 | Berechnung eines Ratings
#
# Hier findest du zwei Beispielrechnungen, für die blau bzw. orange markierten Bewertungen in der Rating-Tabelle
#
# * ${\color{blue}{\textbf{2}}} = 1 \cdot 2 + 0 \cdot 2$
# *  ${\color{orange}{\textbf{4}}} = 1 \cdot 3 + 1 \cdot 1$
#
# <div style="text-align:center">
# <img src="../figs/AB1_help2_1.png" width="550", class="center">
# </div>
#
#
# Übertrage diese Rechnung auf die fehlenden Ratings.
