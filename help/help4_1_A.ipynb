# %% [markdown]
# # Formel für den Fehler | Tipp 1
#
#
# <div style="text-align:left">
# <img src="../figs/AB3_A2_b_RP.png" width="380", class="center">
# </div>
#
# Wie nah ist das Ergebnis der Vorhersage-Matrix an der tatsächlichen Rating-Matrix `R`?
# Du kannst zum Beispiel die Differenz zwischen jedem einzelnen Eintrag  der Rating-Matrix `R` und der Vorhersage-matrix `P` berechnen:
#
# `(r11-p11) + (r12-p12) + ...`
#
# Liefert dies schon ein  sinnvolles Fehlermaß? Oder sollte die Formel noch angepasst werden?
