# %% [markdown]
# # Tipp 1 | Berechnung eines Ratings
#
# Betrachte die folgende Darstellung der drei Tabellen. Wie ergibt sich die
# * blau markierte  Bewertung
# * die orange markierte Bewertung
#
# in der Rating-Tabelle aus den **Zeilen der  User-Tabelle** und den **Spalten der Movie-Tabelle**. Notiere deine Rechnung.
#
#
#
# <div style="text-align:center">
# <img src="../figs/AB1_help2_1.png" width="650", class="center">
# </div>
#
#
#
# Übertrage deine Rechnung auf die fehlenden Ratings.
#
# **Bei Bedarf findest du hier einen weiteren [Tipp](./help2_2.ipynb).**
