# %% [markdown]
# # Tipp 1  | Zusammenhänge in der Rating-Tabelle
#
# Vergleiche die folgenden Zeilen oder Spalten miteinander:
#
# * Zeile 1 und Zeile 3
# * Spalte 1 und Spalte 4
# * Zeilen 2, 3 und 4
#
# Welche Zusammenhänge oder Ähnlichkeiten sind zu erkennen?
#
# **Falls du Schwierigkeiten hast, den Zusammenhang zwischen Zeile 2,3 und 4 zu erkennen, kannst du dir hier einen weiteren [Tipp](../help/help1_2.ipynb) ansehen.**
