# %% [markdown]
# # Tipp 2 | Zusammenhänge in der Rating-Tabelle
#
# Wie ergibt sich die Zeile 4 aus den Zeilen 2 und 3?
#
# `Zeile 4 = ...?`
#
# Was sagt dies über den Geschmack der Nutzer 2, 3 und 4 aus?
